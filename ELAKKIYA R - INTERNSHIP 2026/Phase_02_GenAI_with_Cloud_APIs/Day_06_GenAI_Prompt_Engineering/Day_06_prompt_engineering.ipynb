# %%
# !pip install langchain langchain-groq langchain-community langchain-core --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import os
from langchain_groq  import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

os.environ["GROQ_API_KEY"] = "YOUR_GROQ_API_KEY"

llm=ChatGroq(model="llama-3.3-70b-versatile",temperature=0)
#no shot
prompt=PromptTemplate(
    input_variables=["instruction"],
    template="Follow the instruction and provide theoutput clearly:\n\nInstruction:{instruction}\n\nAnswer:"
)

parser = StrOutputParser()

chain = prompt | llm | parser

response = chain.invoke({
    "instruction":"Translate 'Are you mad?' to Tamil"
})

print(response)
# Out:
# நீ பைத்தியமா? (Nee baythiyama?)

# %%
#Few shot
prompt=PromptTemplate(
    input_variables=["instruction"],
    template="""
    English to Tamil colour:

    English:apple
    Tamil:சிவப்பு
    Follow the instruction and provide theoutput clearly:

    Instruction:{instruction}

    Answer:
    """
)

chain = prompt | llm | parser

response = chain.invoke({
    "instruction":"dragon"
})

print(response)
# Out:
# டிராகன் என்பது ஒரு உயிரினம் அல்ல, ஒரு கற்பனை ஜீவி. எனவே அதற்கு நிறம் கூற முடியாது. ஆனால் பொதுவாக டிராகன்கள் சித்தரிக்கப்படும் நிறம் சிவப்பு அல்லது கருப்பு ஆகும்.
#
# சிவப்பு - டிராகனின் பொதுவான நிறம்
# கருப்பு - டிராகனின் மற்றொரு பொதுவான நிறம்

# %%
#tree of thoughts
prompt=PromptTemplate(
    input_variables=["instruction"],
    template="""
    Generate 4 code for the given instruction in different ways and based on the time complexity and space complexity evaluate the solutions and give the best path and give the final answer.
Format:

Instruction:{instruction}

Answer 1:
<code>

Answer 2:
<code>

Answer 3:
<code>

Answer 4:
<code>

Evaluation:
<evaluate all 4 answers and evaluate which is best>

Best Path:
<code Number>

Final Answer:
<code>
    """
)

chain = prompt | llm | parser

response = chain.invoke({
    "instruction":"solve pallindrome in leetcode using java"
})

print(response)
# Out:
# Instruction: Solve palindrome in LeetCode using Java
#
# Answer 1:
# ```java
# public class Solution {
#     public boolean isPalindrome(String s) {
#         String reversed = new StringBuilder(s).reverse().toString();
#         return s.equals(reversed);
#     }
# }
# ```
#
# Answer 2:
# ```java
# public class Solution {
#     public boolean isPalindrome(String s) {
#         int left = 0, right = s.length() - 1;
#         while (left < right) {
#             if (s.charAt(left) != s.charAt(right)) {
#                 return false;
#             }
#             left++;
#             right--;
#         }
#         return true;
#     }
# }
# ```
#
# Answer 3:
# ```java
# public class Solution {
#     public boolean isPalindrome(String s) {
#         char[] chars = s.toCharArray();
#         int left = 0, right = chars.length - 1;
#         while (left < right) {
#             if (chars[left] != chars[right]) {
#                 return false;
#             }
#             left++;
#             right--;
#         }
#         return true;
#     }
# }
# ```
#
# Answer 4:
# ```java
# public class Solution {
#     public boolean isPalindrome(String s) {
#         for (int i = 0; i < s.length() / 2; i++) {
#             if (s.charAt(i) != s.charAt(s.length() - 1 - i)) {
#                 return false;
#             }
#         }
#         return true;
#     }
# }
# ```
#
# Evaluation:
# - Answer 1 has a time complexity of O(n) and a space complexity of O(n) due to the creation of a new string.
# - Answer 2 has a time complexity of O(n) and a space complexity of O(1) as it only uses a constant amount of space.
# - Answer 3 has a time complexity of O(n) and a space complexity of O(n) due to the creation of a character array.
# - Answer 4 has a time complexity of O(n) and a space complexity of O(1) as it only uses a constant amount of space.
#
# Considering the time and space complexities, Answer 2 and Answer 4 are the most efficient solutions. However, Answer 2 is more concise and easier to understand.
#
# Best Path:
# 2
#
# Final Answer:
# ```java
# public class Solution {
#     public boolean isPalindrome(String s) {
#         int left = 0, right = s.length() - 1;
#         while (left < right) {
#             if (s.charAt(left) != s.charAt(right)) {
#                 return false;
#             }
#             left++;
#             right--;
#         }
#         return true;
#     }
# }
# ```

# %%
# !pip install twilio --quiet

# %%
import os
from getpass import getpass
from twilio.rest import Client

# --- Twilio credentials ---
TW_SID = os.environ.get('sid')
TW_TOKEN = os.environ.get('token')

if not TW_SID or not TW_TOKEN:
    print("Enter your Twilio Account SID and Auth Token:")
    TW_SID = getpass("Twilio SID: ")
    TW_TOKEN = getpass("Twilio Token: ")

FROM = 'whatsapp:+14155238886'
TO = input("Enter your whatsapp number (e.g. +91xxxxxxxxxx): ").strip()

if not TO.startswith('whatsapp:'):
    TO = f'whatsapp:{TO}'

client = Client(TW_SID, TW_TOKEN)

# Extract the instruction from the AI model's response
instruction_start_marker = "Instruction: "
instruction_end_marker = "\n\nAnswer 1:"

instruction_start_index = response.find(instruction_start_marker)
instruction = "Could not find instruction." # Default value
if instruction_start_index != -1:
    instruction_start_index += len(instruction_start_marker)
    instruction_end_index = response.find(instruction_end_marker, instruction_start_index)
    if instruction_end_index != -1:
        instruction = response[instruction_start_index:instruction_end_index].strip()
    else:
        # Fallback if the 'Answer 1:' marker is not found (e.g., if there's no code generated)
        # Try to find the next newline after the instruction_start_marker
        next_newline_index = response.find('\n', instruction_start_index)
        if next_newline_index != -1:
            instruction = response[instruction_start_index:next_newline_index].strip()


# Extract the final answer code from the AI model's response
start_marker = "Final Answer:\n```java\n"
end_marker = "\n```"

start_index = response.find(start_marker)
if start_index != -1:
    start_index += len(start_marker)
    end_index = response.find(end_marker, start_index)
    if end_index != -1:
        final_answer = response[start_index:end_index].strip()
    else:
        final_answer = "Could not parse the final answer code block." # Fallback if end marker is not found
else:
    final_answer = "Could not find 'Final Answer:' in the response." # Fallback if start marker is not found

message_body = f"Problem: {instruction}\n\nOptimal Code:\n{final_answer}"

msg = client.messages.create(
    body=message_body,
    from_=FROM,
    to=TO
)

print("Message sent successfully!")
print("Message SID:", msg.sid)
# Out:
# Enter your Twilio Account SID and Auth Token:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1867/3643080876.py in <cell line: 0>()
#       9 if not TW_SID or not TW_TOKEN:
#      10     print("Enter your Twilio Account SID and Auth Token:")
# ---> 11     TW_SID = getpass("Twilio SID: ")
#      12     TW_TOKEN = getpass("Twilio Token: ")
#      13
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
