# %%
# !pip install chromadb sentence-transformers -q
print("Installation complete")
# Out:
# Installation complete

# %%
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer
import chromadb

print(f"chroma db version: {chromadb.__version__}")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1534         try:
# -> 1535             return importlib.import_module("." + module_name, self.__name__)
#    1536         except Exception as e:
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in <module>
#     212 if is_peft_available():
# --> 213     from peft import PeftModel
#     214
#
# /usr/local/lib/python3.12/dist-packages/peft/__init__.py in <module>
#      16
# ---> 17 from .auto import (
#      18     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#
# /usr/local/lib/python3.12/dist-packages/peft/auto.py in <module>
#      31 from .config import PeftConfig
# ---> 32 from .peft_model import (
#      33     PeftModel,
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in <module>
#      37 from torch.nn import BCEWithLogitsLoss, CrossEntropyLoss, MSELoss
# ---> 38 from transformers import Cache, DynamicCache, EncoderDecoderCache, PreTrainedModel
#      39 from transformers.modeling_outputs import QuestionAnsweringModelOutput, SequenceClassifierOutput, TokenClassifierOutput
#
# ImportError: cannot import name 'EncoderDecoderCache' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_27362/1178612827.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 from sentence_transformers import SentenceTransformer
#       5 import chromadb
#       6
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/__init__.py in <module>
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/base/__init__.py in <module>
#      12     RoundRobinBatchSampler,
#      13 )
# ---> 14 from .trainer import BaseTrainer
#      15 from .training_args import BaseTrainingArguments, BatchSamplers, MultiDatasetBatchSamplers
#      16
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/base/trainer.py in <module>
#      17 from torch import nn
#      18 from torch.utils.data import BatchSampler, ConcatDataset, DataLoader, RandomSampler
# ---> 19 from transformers import EvalPrediction, PreTrainedTokenizerBase, Trainer, TrainerCallback
#      20 from transformers.feature_extraction_utils import FeatureExtractionMixin
#      21 from transformers.image_processing_utils import BaseImageProcessor
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1523             value = self._get_module(name)
#    1524         elif name in self._class_to_module.keys():
# -> 1525             module = self._get_module(self._class_to_module[name])
#    1526             value = getattr(module, name)
#    1527         else:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1535             return importlib.import_module("." + module_name, self.__name__)
#    1536         except Exception as e:
# -> 1537             raise RuntimeError(
#    1538                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1539                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.trainer because of the following error (look up to see its traceback):
# cannot import name 'EncoderDecoderCache' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)

# %%
documents = [
    "ETL is used to clean and transform data",
    "A vehicle is a mode of transportation",
    "Cars and trucks are popular automobiles",
    "SQL is used to quwry databases",
    "Machine learning trains models on data",
]

query_keyword = "vehicle"

print("=" * 60)
print(f"KEYWORD SEARCH FOR: {query_keyword}")
print("=" * 60)

for i,doc in enumerate(documents):
  if query_keyword.lower() in doc.lower():
    print(f"FOUND [doc_{i}]: {doc}")
  else:
    print(f"MISSED [doc_{i}]: {doc}")

# %%
# !pip install llama-index llama-index-llms-groq sentence-transformers --q

# %%
# !pip install llama-index-embeddings-huggingface --q

# %%
import os
from textwrap import dedent

os.makedirs("data",exist_ok=True)

file_path="data/myresume.txt"

content=dedent(
"""
    ELAKKIYA R
Phone: +91 6381047342 | Email: elakiii07@gmail.com | GitHub | LinkedIn | Self Intro

EDUCATION
B.Tech AI & DS - Sri Eshwar College of Engineering | CGPA: 8.14 (Up to 3rd Semester) | 2024 - 2028
HSC - Akshaya Academy Matric Higher Secondary School | 90.6% | 2022 - 2024
SSLC - Akshaya Academy Matric Higher Secondary School | 90.8% | 2021 - 2022

INTERNSHIP EXPERIENCE
MERN Internship - AlgoTutor | Dec 2025
- Gained hands-on experience in MERN stack development using MongoDB, Express.js, React, and Node.js.
- Built sample web applications and RESTful APIs.
- Worked on frontend-backend integration, authentication, database schema design, and CRUD operations.
- Improved problem-solving, teamwork, and full-stack development skills.

PROJECTS

1. Chitti AI - Conversational Image Analysis Chatbot | 2025
- Built a full-stack multimodal platform for real-time image-based AI conversations using YOLO and Groq Llama-4 Vision APIs.
- Developed a responsive React frontend with persistent chat memory and optimized image processing workflows.
Tech Stack: React.js, Tailwind CSS, FastAPI, Python, YOLO, Groq API, MongoDB

2. CampusFind - Lost & Found System | 2025
- Developed a full-stack Lost & Found web application for reporting, searching, and matching lost items with image upload support.
- Built responsive user interfaces and RESTful APIs for seamless frontend-backend interaction.
Tech Stack: MongoDB, Express.js, React.js, Node.js, Tailwind CSS

3. AI-Based Internship Recommendation Engine | 2025
- Developed an AI Internship Recommendation System that suggests relevant internship opportunities based on user skills, interests, and profiles.
- Built responsive dashboards and integrated intelligent recommendation workflows for career guidance.
Tech Stack: React.js, Node.js, Express.js, MongoDB, Python, Tailwind CSS

ACHIEVEMENTS
- Third Prize - Mini Project Review, Sri Eshwar College of Engineering
- Top 20 Finalist - TechSprint 2025, GDG on Campus CIT
- Student Mentor - Sri Eshwar College of Engineering
- Pre-Finalist - National Level Shine Healthcare Hackathon, Trichy Cohort
- Third Place - Freshathon, Intra-College Hackathon at Sri Eshwar College of Engineering

CERTIFICATIONS
- Introduction to Machine Learning - Guvi (2025)
- The Complete Java Programmer - Udemy (2025)
- Introduction to Data Science - LinkedIn (2024)

CODING PROFILES
- LeetCode: Solved 100+ problems | Contests Attended: 2 | Rating: 1440 | Global Rank: 579,003
- Skill Rack: Solved 800+ problems | 266 Bronzes | 8 Certifications | Global Rank: 31,869
- CodeChef: Problem Solver - Bronze Badge | Global Rank: 183,276

TECHNICAL SKILLS
Programming Languages: C, C++, Python, Java, HTML, CSS, JavaScript
Core Frameworks: DSA, OOP, React.js, Express.js, Node.js
Tools: Canva, GitHub, Tableau, Power BI, Vercel, Excel, Jupyter Notebook
Databases: MySQL, MongoDB

    """
).strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)

print("file loaded successfully")

# %%
# !pip install transformers==4.37.0 sentence-transformers --q

import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

os.environ["GROQ_API_KEY"] = "groq_api_key_here"

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

file_path="data/myresume.txt"
documents=SimpleDirectoryReader(input_files=[file_path]).load_data()

index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

query_engine=index.as_query_engine(llm=llm)

response=query_engine.query("Summarize the content of this document in 3 bullet points")
print("\n Document Summary:\n", response)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-llms-openai-like 0.5.3 requires transformers<5,>=4.37.0, but you have transformers 5.9.0 which is incompatible.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1534     The advantage of using `torch._check(cond, msg, error_type)` over `if cond: raise error_type(msg)` is that the former
# -> 1535     works as a truthfulness hint for TorchDynamo, instead of failing with a data-dependent control flow error during compilation.
#    1536
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.cohere.configuration_cohere'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_27362/1953528888.py in <cell line: 0>()
#      11 llm=Groq(model="llama-3.1-8b-instant")
#      12
# ---> 13 embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")
#      14
#      15 file_path="data/myresume.txt"
#
# /usr/local/lib/python3.12/dist-packages/llama_index/embeddings/huggingface/base.py in __init__(self, model_name, tokenizer_name, pooling, max_length, query_instruction, text_instruction, normalize, model, tokenizer, embed_batch_size, cache_folder, trust_remote_code, device, callback_manager, parallel_process, target_devices, show_progress_bar, **model_kwargs)
#     158             raise ValueError("The `model_name` argument must be provided.")
#     159
# --> 160         model = SentenceTransformer(
#     161             model_name,
#     162             device=device,
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/SentenceTransformer.py in __init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, token, use_auth_token, truncate_dim)
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/SentenceTransformer.py in _load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code)
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/models/Transformer.py in __init__(self, model_name_or_path, max_seq_length, model_args, cache_dir, tokenizer_args, do_lower_case, tokenizer_name_or_path)
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/models/Transformer.py in _load_model(self, model_name_or_path, config, cache_dir, **model_args)
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     538         try:
#     539             return getattribute_from_module(transformers_module, attr)
# --> 540         except ValueError:
#     541             raise ValueError(f"Could not find {attr} neither in {module} nor in {transformers_module}!")
#     542     else:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in keys(self)
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1523         _is_tracing |= is_fake_tensor(tensor)
#    1524         _is_tracing |= is_jax_jitting(tensor)
# -> 1525
#    1526     return _is_tracing
#    1527
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1535     works as a truthfulness hint for TorchDynamo, instead of failing with a data-dependent control flow error during compilation.
#    1536
# -> 1537     All checks using this method can be disabled in production environments by setting `TRANSFORMERS_DISABLE_TORCH_CHECK=1`.
#    1538
#    1539     Args:
#
# RuntimeError: Failed to import transformers.models.cohere.configuration_cohere because of the following error (look up to see its traceback):
# No module named 'transformers.models.cohere.configuration_cohere'
