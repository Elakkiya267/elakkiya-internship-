# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/student_performance.csv')

# %%
df.shape
# Out:
# (30, 13)

# %%
df.head(10)
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
# 5        1006   Meera Joshi   20  Female       Electronics         2
# 6        1007   Kiran Kumar   21    Male             Civil         2
# 7        1008   Divya Singh   19  Female  Computer Science         2
# 8        1009  Rahul Mishra   20    Male        Mechanical         2
# 9        1010    Ananya Das   19  Female  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# ...

# %%
print(df.iloc[:, 4].shape)
# Out:
# (30,)

# %%
print(df.columns.tolist())
# Out:
# ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
print(df.dtypes)
# Out:
# student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %% [markdown]
# If you meant to remove the entire column, you can use `df.drop(columns=['column_name'], inplace=True)`.
#
# If you want to remove rows where a specific column has `NaN` values, you can use `df.dropna(subset=['column_name'], inplace=True)`.

# %%
import numpy as np
df.loc[df.index[:5],'math_score']=np.nan
df.isna().sum()
# Out:
# student_id                0
# name                      0
# age                       0
# gender                    0
# department                0
# semester                  0
# math_score               20
# science_score             0
# english_score             0
# programming_score         0
# attendance_percentage     0
# city                      0
# admission_year            0
# dtype: int64

# %%
# Out:
# student_id                0
# name                      0
# age                       0
# gender                    0
# department                0
# semester                  0
# math_score               20
# science_score             0
# english_score             0
# programming_score         0
# attendance_percentage     0
# city                      0
# admission_year            0
# dtype: int64

# %%
df.loc[0:4,'math_score']=None
df.isnull().sum()
# Out:
# student_id                0
# name                      0
# age                       0
# gender                    0
# department                0
# semester                  0
# math_score               20
# science_score             0
# english_score             0
# programming_score         0
# attendance_percentage     0
# city                      0
# admission_year            0
# dtype: int64

# %%
df['gender'].count()
# Out:
# np.int64(30)

# %%
df['semester'].count()
# Out:
# np.int64(30)

# %%
print(df['department'].unique())

print("------------------------------------------------------------------")

print(df['department'].value_counts)
# Out:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
# ------------------------------------------------------------------
# <bound method IndexOpsMixin.value_counts of 0     Computer Science
# 1     Computer Science
# 2          Electronics
# 3           Mechanical
# 4     Computer Science
# 5          Electronics
# 6                Civil
# 7     Computer Science
# 8           Mechanical
# 9     Computer Science
# 10         Electronics
# 11               Civil
# 12    Computer Science
# 13          Mechanical
# 14    Computer Science
# 15         Electronics
# 16               Civil
# 17    Computer Science
# 18          Mechanical
# 19    Computer Science
# 20         Electronics
# 21    Computer Science
# 22               Civil
# 23          Mechanical
# 24    Computer Science
# 25         Electronics
# 26    Computer Science
# 27               Civil
# 28          Mechanical
# 29    Computer Science
# Name: department, dtype: object>

# %%
high_attendance=df[df['attendance_percentage']<=75]
print(f"Students with attendance less than or equal to 75%:{len(high_attendance)}")
print(high_attendance[['name','department','attendance_percentage']])
# Out:
# Students with attendance less than or equal to 75%:7
#              name        department  attendance_percentage
# 5     Meera Joshi       Electronics                     72
# 8    Rahul Mishra        Mechanical                     68
# 14    Ajay Tiwari  Computer Science                     75
# 16   Manoj Pandey             Civil                     65
# 20  Harish Pillai       Electronics                     74
# 22   Sanjay Dubey             Civil                     70
# 27  Sunita Pillai             Civil                     73

# %%
df['total_score']=df['math_score']+df['science_score']+df['english_score']+df['programming_score']
top_student=df.loc[df['total_score'].idxmax()]
print("Top student:")
print(f"Name:{top_student['name']}")
print(f"Departmentr:{top_student['department']}")
print(f"Total Score:{top_student['total_score']}")
print(f"Attendance:{top_student['attendance_percentage']}%")
# Out:
# Top student:
# Name:Ananya Das
# Departmentr:Computer Science
# Total Score:371.0
# Attendance:98%
